# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_dir = './4365857.jpg'

# %%
img = cv2.imread(img_dir, cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()

# %%
img
# Out:
# array([[[ 25,  52,   0],
#         [ 47,  74,  19],
#         [ 69,  98,  40],
#         ...,
#         [157, 153,  17],
#         [173, 166,  33],
#         [186, 178,  45]],
#
#        [[ 54,  81,  28],
#         [ 47,  76,  20],
#         [ 60,  89,  33],
#         ...,
#         [155, 152,  19],
#         [145, 141,   8],
#         [157, 150,  18]],
#
#        [[ 88, 116,  65],
#         [ 59,  87,  36],
#         [ 49,  77,  26],
#         ...,
#         [162, 163,  36],
#         [139, 138,  12],
#         [138, 137,  10]],
#
#        ...,
#
#        [[ 86, 103,  51],
#         [ 90, 107,  55],
#         [ 92, 106,  55],
#         ...,
#         [128, 145, 101],
#         [127, 143, 104],
#         [126, 142, 105]],
#
#        [[ 93, 107,  56],
#         [111, 125,  74],
#         [123, 137,  86],
#         ...,
#         [131, 146, 103],
#         [130, 145, 106],
#         [130, 144, 108]],
#
#        [[142, 156, 105],
#         [137, 151, 100],
#         [130, 144,  93],
# ...

# %%
def get_img(path):
    im_bgr = cv2.imread(path)
    im_rgb = im_bgr[:, :, ::-1]
    #print(im_rgb)
    return im_rgb

# %%
img_dir = './4365857.jpg'
a = get_img(img_dir)

# %%
a
# Out:
# array([[[ 25,  52,   0],
#         [ 47,  74,  19],
#         [ 69,  98,  40],
#         ...,
#         [157, 153,  17],
#         [173, 166,  33],
#         [186, 178,  45]],
#
#        [[ 54,  81,  28],
#         [ 47,  76,  20],
#         [ 60,  89,  33],
#         ...,
#         [155, 152,  19],
#         [145, 141,   8],
#         [157, 150,  18]],
#
#        [[ 88, 116,  65],
#         [ 59,  87,  36],
#         [ 49,  77,  26],
#         ...,
#         [162, 163,  36],
#         [139, 138,  12],
#         [138, 137,  10]],
#
#        ...,
#
#        [[ 86, 103,  51],
#         [ 90, 107,  55],
#         [ 92, 106,  55],
#         ...,
#         [128, 145, 101],
#         [127, 143, 104],
#         [126, 142, 105]],
#
#        [[ 93, 107,  56],
#         [111, 125,  74],
#         [123, 137,  86],
#         ...,
#         [131, 146, 103],
#         [130, 145, 106],
#         [130, 144, 108]],
#
#        [[142, 156, 105],
#         [137, 151, 100],
#         [130, 144,  93],
# ...

# %%
img_np = np.int64(img)

# %%
temp = np.where(img_np >= 90, img_np, 0)

# %%
plt.imshow(temp)
plt.show()

# %%
temp = np.where(img_np >= 100, img_np, 0)
plt.imshow(temp)
plt.show()

# %%
temp = np.where(img_np >= 150, img_np, 0)
plt.imshow(temp)
plt.show()

# %%
temp = np.where(img_np >= 190, img_np, 0)
plt.imshow(temp)
plt.show()

# %%
temp = np.where(img_np >= 200, img_np, 0)
plt.imshow(temp)
plt.show()
